# %%
using DataFrames, PyPlot;
c₁="#838300";
c₂="#008383";
c₃="#830083";

# %%
data = readtable("data.dat",separator='\t',header=true);
#data[:BER_1] = log10(data[:BER_1]);
#data[:BER_6] = log10(data[:BER_6]);
display(data)
# Out:
# 8×4 DataFrames.DataFrame
# │ Row │ SNR │ BER_1    │ BER_6    │ AWGN_1   │
# ├─────┼─────┼──────────┼──────────┼──────────┤
# │ 1   │ 14  │ 0.003422 │ 4.6e-5   │ 0.0      │
# │ 2   │ 12  │ 0.009914 │ 0.000586 │ 3.6e-5   │
# │ 3   │ 10  │ 0.023236 │ 0.005448 │ 0.000906 │
# │ 4   │ 8   │ 0.040472 │ 0.022938 │ 0.006902 │
# │ 5   │ 6   │ 0.066948 │ 0.05865  │ 0.026138 │
# │ 6   │ 4   │ 0.103188 │ 0.107266 │ 0.062824 │
# │ 7   │ 2   │ 0.148926 │ 0.171636 │ 0.11684  │
# │ 8   │ 0   │ 0.19804  │ 0.234544 │ 0.17809  │

# %%
fig = figure("Static Error",figsize=(12,8)) # Create a new figure
ax = axes();
p2 = semilogy(data[:SNR],data[:BER_1],color=c₁,linewidth=2,linestyle="-",marker="s");
p1 = semilogy(data[:SNR],data[:BER_6],color=c₂,linewidth=2,linestyle="--",marker="o");
p1 = semilogy(data[:SNR],data[:AWGN_1],color=c₃,linewidth=2,linestyle=":",marker="*");

ylabel("BER");
xlabel("SNR [dB]");
title("SNR Vs. BER");
legend([L"ISI - L_f + 1 = 1",L"ISI - L_f + 1 = 6",L"AWGN - L_f + 1 = 1"]);

fig[:canvas][:draw]()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f42b6af2e10>)
